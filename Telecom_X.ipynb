# %% [markdown]
# #📌 Extracción

# %%
# Importamos las librerías necesarias para trabajar con datos
import requests
import pandas as pd

# Definimos la dirección del archivo JSON con datos de clientes
enlace_datos = "https://raw.githubusercontent.com/adsecv/ctx_aec_1/refs/heads/main/Base-de-datos/TelecomX_Data.json"

# Obtenemos los datos desde la URL
respuesta = requests.get(enlace_datos)

# Convertimos los datos JSON en un objeto de Python
datos_json = respuesta.json()

# Creamos una tabla con los datos obtenidos
tabla_clientes = pd.DataFrame(datos_json)

# Visualizamos la tabla para explorar los datos
tabla_clientes
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
# Aplanamos los datos JSON para trabajar con una tabla más simple
tabla_normalizada = pd.json_normalize(datos_json)

# Mostramos la tabla normalizada para verificar su contenido
tabla_normalizada
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
# Visualizamos la estructura y tipos de datos de la tabla normalizada
tabla_normalizada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
# Exploramos los valores únicos de cada columna en la tabla
for columna in tabla_normalizada.columns:
    cantidad_unicos = tabla_normalizada[columna].nunique()
    print(f"Columna '{columna}' tiene {cantidad_unicos} valores únicos")
    if cantidad_unicos < 20:  # Mostramos valores solo si son pocos
        valores = tabla_normalizada[columna].unique()
        print(f"Valores: {valores}")
        print("=" * 60)  # Separador para claridad en la salida
# Out:
# Columna 'customerID' tiene 7267 valores únicos
# Columna 'Churn' tiene 3 valores únicos
# Valores: ['No' 'Yes' '']
# ...
# Columna 'customer.gender' tiene 2 valores únicos
# Valores: ['Female' 'Male']
# ...
# Columna 'customer.SeniorCitizen' tiene 2 valores únicos
# Valores: [0 1]
# ...
# Columna 'customer.Partner' tiene 2 valores únicos
# Valores: ['Yes' 'No']
# ...
# Columna 'customer.Dependents' tiene 2 valores únicos
# Valores: ['Yes' 'No']
# ...
# Columna 'customer.tenure' tiene 73 valores únicos
# Columna 'phone.PhoneService' tiene 2 valores únicos
# Valores: ['Yes' 'No']
# ...
# Columna 'phone.MultipleLines' tiene 3 valores únicos
# Valores: ['No' 'Yes' 'No phone service']
# ...
# Columna 'internet.InternetService' tiene 3 valores únicos
# Valores: ['DSL' 'Fiber optic' 'No']
# ...
# Columna 'internet.OnlineSecurity' tiene 3 valores únicos
# Valores: ['No' 'Yes' 'No internet service']
# ...
# Columna 'internet.OnlineBackup' tiene 3 valores únicos
# Valores: ['Yes' 'No' 'No internet service']
# ...

# %%
# Comprobamos si existen filas duplicadas en la tabla
total_duplicados = tabla_normalizada.duplicated().sum()
print(f"Se encontraron {total_duplicados} filas duplicadas en el dataset.")
# Out:
# Se encontraron 0 filas duplicadas en el dataset.

# %%
# Revisamos la presencia de valores nulos en la tabla
nulos_por_columna = tabla_normalizada.isnull().sum()
print(f"Cantidad de valores nulos por columna:\n{nulos_por_columna}")
# Out:
# Cantidad de valores nulos por columna:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
# Comprobamos si hay celdas con cadenas vacías o espacios en blanco
cadenas_vacias = tabla_normalizada.apply(lambda col: col.astype(str).str.strip() == '').sum()
print(f"Cantidad de valores vacíos o en blanco por columna:\n{cadenas_vacias}")
# Out:
# Cantidad de valores vacíos o en blanco por columna:
# customerID                     0
# Churn                        224
# customer.gender                0
# customer.SeniorCitizen         0
# customer.Partner               0
# customer.Dependents            0
# customer.tenure                0
# phone.PhoneService             0
# phone.MultipleLines            0
# internet.InternetService       0
# internet.OnlineSecurity        0
# internet.OnlineBackup          0
# internet.DeviceProtection      0
# internet.TechSupport           0
# internet.StreamingTV           0
# internet.StreamingMovies       0
# account.Contract               0
# account.PaperlessBilling       0
# account.PaymentMethod          0
# account.Charges.Monthly        0
# account.Charges.Total         11
# dtype: int64

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
